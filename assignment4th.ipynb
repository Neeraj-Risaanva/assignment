# %% [markdown]
# ## Assignment - Visualiztion of data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(color_codes=True)

# %% [markdown]
# ## Import the data from AutoMPG data file assign it to the Variable called mpg-df

# %%
mpg_df=pd.read_csv("auto-mpg.csv")

# %% [markdown]
# ### Perform basic EDA to understand the structure of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   df=pd.read_csv  398 non-null    float64
#  1   cylinders       398 non-null    int64
#  2   displacement    398 non-null    float64
#  3   horsepower      398 non-null    object
#  4   weight          398 non-null    int64
#  5   acceleration    398 non-null    float64
#  6   model year      398 non-null    int64
#  7   origin          398 non-null    int64
#  8   car name        398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.head()
# Out:
#    df=pd.read_csv  cylinders  displacement horsepower  weight  acceleration  \
# 0            18.0          8         307.0        130    3504          12.0
# 1            15.0          8         350.0        165    3693          11.5
# 2            18.0          8         318.0        150    3436          11.0
# 3            16.0          8         304.0        150    3433          12.0
# 4            17.0          8         302.0        140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.sum()
# Out:
# df=pd.read_csv                                               9358.8
# cylinders                                                      2171
# displacement                                                76983.5
# horsepower        1301651501501401982202152251901701601502259595...
# weight                                                      1182229
# acceleration                                                 6196.1
# model year                                                    30252
# origin                                                          626
# car name          chevrolet chevelle malibubuick skylark 320plym...
# dtype: object

# %%
df.dtypes
# Out:
# df=pd.read_csv    float64
# cylinders           int64
# displacement      float64
# horsepower         object
# weight              int64
# acceleration      float64
# model year          int64
# origin              int64
# car name           object
# dtype: object

# %%
df.describe()
# Out:
#        df=pd.read_csv   cylinders  displacement       weight  acceleration  \
# count      398.000000  398.000000    398.000000   398.000000    398.000000
# mean        23.514573    5.454774    193.425879  2970.424623     15.568090
# std          7.815984    1.701004    104.269838   846.841774      2.757689
# min          9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%         17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%         23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%         29.000000    8.000000    262.000000  3608.000000     17.175000
# max         46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### Check and handle the missing values

# %%
df.isnull().sum()
# Out:
# df=pd.read_csv    0
# cylinders         0
# displacement      0
# horsepower        0
# weight            0
# acceleration      0
# model year        0
# origin            0
# car name          0
# dtype: int64

# %% [markdown]
# ### Create a plot to check the relationship between Horsepower & Acceleration

# %%
sns.catplot(x='horsepower',y='acceleration', data=df)
plt.show()

# %%
sns.countplot(x="horsepower",data=mpg_df)
plt.show()

# %%
sns.catplot(x="horsepower",y="acceleration",data=df)
plt.show()

# %% [markdown]
# ### Generate Subplot to display the histrograms for Acceleration , Displacement and Weight and kilometer_ per_litre

# %%
plt.hist(mpg_df["acceleration"])
plt.show()

# %%
plt.hist(mpg_df["displacement"])
plt.show()

# %%
plt.hist(mpg_df["weight"])
plt.show()

# %% [markdown]
# ### Create a plot to check the relationship between Displacement and Weight for origin 2 ,color the datapoint based on no. of cylinders

# %%
df = mpg_df[mpg_df.origin==2]
df
# Out:
#      df=pd.read_csv  cylinders  displacement horsepower  weight  acceleration  \
# 19             26.0          4          97.0         46    1835          20.5
# 20             25.0          4         110.0         87    2672          17.5
# 21             24.0          4         107.0         90    2430          14.5
# 22             25.0          4         104.0         95    2375          17.5
# 23             26.0          4         121.0        113    2234          12.5
# ..              ...        ...           ...        ...     ...           ...
# 354            34.5          4         100.0          ?    2320          15.8
# 359            28.1          4         141.0         80    3230          20.4
# 360            30.7          6         145.0         76    3160          19.6
# 375            36.0          4         105.0         74    1980          15.3
# 394            44.0          4          97.0         52    2130          24.6
#
# ...

# %% [markdown]
# ### Display the frequency distribution of the origin variable

# %%
plt.hist(mpg_df['origin'])
# Out:
# (array([249.,   0.,   0.,   0.,   0.,  70.,   0.,   0.,   0.,  79.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Check the relationship of multiple variable wrt. kilometer_per_litre

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Display the average weight based on no. of cylinder presents

# %%
arr_cyl=mpg_df.groupby('cylinders')['weight'].sum()
arr_cyl_avg=arr_cyl/295
arr_cyl_avg
# Out:
# cylinders
# 3      32.522034
# 4    1596.128814
# 5      31.559322
# 6     910.681356
# 8    1436.664407
# Name: weight, dtype: float64

# %%
mpg_df.groupby('cylinders').weight.mean()
# Out:
# cylinders
# 3    2398.500000
# 4    2308.127451
# 5    3103.333333
# 6    3198.226190
# 8    4114.718447
# Name: weight, dtype: float64

# %% [markdown]
# ### Check for the outliers in the dataset

# %%
sns.catplot(x="cylinders",y="weight",kind="box",data=df,palette="Set2")
plt.show()

# %% [markdown]
# ### Plot the correlation for variable

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
 mpg_df.corr()
# Out:
#                 df=pd.read_csv  cylinders  displacement    weight  \
# df=pd.read_csv        1.000000  -0.775396     -0.804203 -0.831741
# cylinders            -0.775396   1.000000      0.950721  0.896017
# displacement         -0.804203   0.950721      1.000000  0.932824
# weight               -0.831741   0.896017      0.932824  1.000000
# acceleration          0.420289  -0.505419     -0.543684 -0.417457
# model year            0.579267  -0.348746     -0.370164 -0.306564
# origin                0.563450  -0.562543     -0.609409 -0.581024
#
#                 acceleration  model year    origin
# df=pd.read_csv      0.420289    0.579267  0.563450
# cylinders          -0.505419   -0.348746 -0.562543
# displacement       -0.543684   -0.370164 -0.609409
# weight             -0.417457   -0.306564 -0.581024
# acceleration        1.000000    0.288137  0.205873
# model year          0.288137    1.000000  0.180662
# origin              0.205873    0.180662  1.000000

# %%
sns.heatmap(df.corr())
plt.show()
